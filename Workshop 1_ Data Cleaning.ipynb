# %%
import pandas as pd

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.498
# 1      AFG      Asia  ...           64.83                   0.498
# 2      AFG      Asia  ...           64.83                   0.498
# 3      AFG      Asia  ...           64.83                   0.498
# 4      AFG      Asia  ...           64.83                   0.498
#
# [5 rows x 41 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = df[['continent','location','date','total_cases','new_cases', 'total_deaths', 'new_deaths', 'population']]

# %%
df
# Out:
#       continent       location  ... new_deaths  population
# 0          Asia    Afghanistan  ...        0.0  38928341.0
# 1          Asia    Afghanistan  ...        0.0  38928341.0
# 2          Asia    Afghanistan  ...        0.0  38928341.0
# 3          Asia    Afghanistan  ...        0.0  38928341.0
# 4          Asia    Afghanistan  ...        0.0  38928341.0
# ...         ...            ...  ...        ...         ...
# 47954       NaN  International  ...        NaN         NaN
# 47955       NaN  International  ...        NaN         NaN
# 47956       NaN  International  ...        NaN         NaN
# 47957       NaN  International  ...        NaN         NaN
# 47958       NaN  International  ...        NaN         NaN
#
# [47959 rows x 8 columns]

# %%
df = df.dropna()
df
# Out:
#       continent     location        date  ...  total_deaths  new_deaths  population
# 0          Asia  Afghanistan  2019-12-31  ...           0.0         0.0  38928341.0
# 1          Asia  Afghanistan  2020-01-01  ...           0.0         0.0  38928341.0
# 2          Asia  Afghanistan  2020-01-02  ...           0.0         0.0  38928341.0
# 3          Asia  Afghanistan  2020-01-03  ...           0.0         0.0  38928341.0
# 4          Asia  Afghanistan  2020-01-04  ...           0.0         0.0  38928341.0
# ...         ...          ...         ...  ...           ...         ...         ...
# 47396    Africa     Zimbabwe  2020-09-30  ...         228.0         0.0  14862927.0
# 47397    Africa     Zimbabwe  2020-10-01  ...         228.0         0.0  14862927.0
# 47398    Africa     Zimbabwe  2020-10-02  ...         228.0         0.0  14862927.0
# 47399    Africa     Zimbabwe  2020-10-03  ...         228.0         0.0  14862927.0
# ...

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df['date']= pd.to_datetime(df['date'])
df.head()
# Out:
#   continent     location       date  ...  total_deaths  new_deaths  population
# 0      Asia  Afghanistan 2019-12-31  ...           0.0         0.0  38928341.0
# 1      Asia  Afghanistan 2020-01-01  ...           0.0         0.0  38928341.0
# 2      Asia  Afghanistan 2020-01-02  ...           0.0         0.0  38928341.0
# 3      Asia  Afghanistan 2020-01-03  ...           0.0         0.0  38928341.0
# 4      Asia  Afghanistan 2020-01-04  ...           0.0         0.0  38928341.0
#
# [5 rows x 8 columns]

# %%
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
start = df['date'] > '2020-06-01'
end = df['date'] < '2020-10-01'

# %%
df = df[start & end]
# Out:
#       continent     location       date  ...  total_deaths  new_deaths  population
# 154        Asia  Afghanistan 2020-06-02  ...         265.0         8.0  38928341.0
# 155        Asia  Afghanistan 2020-06-03  ...         270.0         5.0  38928341.0
# 156        Asia  Afghanistan 2020-06-04  ...         294.0        24.0  38928341.0
# 157        Asia  Afghanistan 2020-06-05  ...         300.0         6.0  38928341.0
# 158        Asia  Afghanistan 2020-06-06  ...         309.0         9.0  38928341.0
# ...         ...          ...        ...  ...           ...         ...         ...
# 47392    Africa     Zimbabwe 2020-09-26  ...         227.0         0.0  14862927.0
# 47393    Africa     Zimbabwe 2020-09-27  ...         227.0         0.0  14862927.0
# 47394    Africa     Zimbabwe 2020-09-28  ...         227.0         0.0  14862927.0
# 47395    Africa     Zimbabwe 2020-09-29  ...         228.0         1.0  14862927.0
# ...

# %%
df.to_csv('covid-data-recent.csv', index = False)

# %% [markdown]
# ### Aggregate the data: continent, location
